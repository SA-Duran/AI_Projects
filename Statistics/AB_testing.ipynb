# %% [markdown]
# # AB Testing examples

# %% [markdown]
# # 1 Classic

# %% [markdown]
# We have a collection of 100 variables $X_i$, each with 100 measurements, and we are looking for the one, theres only one, which correlates to Y. Because of the small samples, some might correlate over this range.

# %%
import pandas as pd
import numpy as np

X = pd.DataFrame(np.random.normal(size=(100,100)), 
                 columns =['X_{}'.format(i+1) for i in range(100)])
X['Y'] = X['X_1'] + np.random.normal(size=100)

# %% [markdown]
# We first calculate pearson correlation, to see how many entries are much larger than 0. Pearson correlation measures the strength and direction of linear relationships between two quantitative variables. Pearson only measures linear relationships and is sensitive to outliers but its a good first estimate.
#
# ### Pearson Correlation Coefficient
#
# Given two variables  $X = (x_1, x_2, ..., x_n), Y = (y_1, y_2, ..., y_n)$
#
# the Pearson correlation coefficient r is calculated as:
#
# $$ r = \frac{\sum_{i=1}^{n} (x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum_{i=1}^{n}(x_i - \bar{x})^2} \cdot \sqrt{\sum_{i=1}^{n}(y_i - \bar{y})^2}} $$
#
# In other words, it is the **covariance between X and Y** divided by the product of their standard deviations:
# $$r = \frac{\text{Cov}(X, Y)}{\sigma_X \cdot \sigma_Y}$$
# - $\bar{x}$ and $ \bar{y} $ are the means of $X $ and $ Y $.
# - $\sigma_X $ and $ \sigma_Y $ are their standard deviations.
# - $ r \in [-1, 1] $ indicates the strength and direction of a **linear** relationship between the two variables.
#
# In scipy pearson correlation the function will return r, the correlation coefficient, and the p value. This last P value refers to the probability of having observed a certain correlation value assuming a Null Hypothesis "There is no correlation between X and Y".
# For instance, a p value smaller than a certain treshold would provide eviden to reject the null hypothesis and suggest a correlation between X and Y.

# %%
from scipy.stats import pearsonr
alpha= 0.05 #normal threshold, those varibale with random correlation
n= len(X.columns)-1
bonferroni_alpha = alpha / n #correction for multiple tests
for xi in X.columns:
      r, p_value = pearsonr(X[xi], X['Y']) #returns r the correlation and the p value
      #probability of having observed the correlation obtained assuming the null hypothesis
      
      if p_value < bonferroni_alpha:
          print(xi, r, p_value, '***')
      elif p_value < alpha:
          print(xi, r, p_value)
      else:
          pass
# Out:
# X_1 0.7813933481084387 8.716821413553202e-22 ***
# X_4 0.2871072454849083 0.0037769506883983603
# X_7 -0.2864429017935232 0.0038620338372247426
# X_9 0.22713886175176873 0.02304892609233149
# X_34 0.28686083086936265 0.00380831157690593
# X_36 -0.21421731352925605 0.03234256984240962
# X_77 -0.20376189661883 0.04201349995420717
# X_83 0.24120451967925927 0.015626301731179505
# X_87 -0.22693659792226556 0.023174570152432416
# X_93 -0.22722310215313282 0.02299676895695564
# Y 0.9999999999999997 0.0 ***

# %% [markdown]
# $X_1$ is the only one passing the bonferroni corrected treshold for the p value. This was indeed the correlated variable. Without correction som othe variables would have turned as a positive correlation.
